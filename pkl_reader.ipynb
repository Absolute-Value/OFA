# %%
import pandas as pd

# %%
data_dir="/data/dataset/imagenet_1k_data"
ans2label_file=f"{data_dir}/class2label_new.pkl"

# %%
forest_read_pickle = pd.read_pickle(ans2label_file)

# %%
forest_read_pickle
# Out:
# {'tench': 1,
#  'ostrich': 10,
#  'goose': 100,
#  'toilet tissue': 1000,
#  'black swan': 101,
#  'tusker': 102,
#  'echidna': 103,
#  'platypus': 104,
#  'wallaby': 105,
#  'koala': 106,
#  'wombat': 107,
#  'jellyfish': 108,
#  'sea anemone': 109,
#  'brambling': 11,
#  'brain coral': 110,
#  'flatworm': 111,
#  'nematode': 112,
#  'conch': 113,
#  'snail': 114,
#  'slug': 115,
#  'sea slug': 116,
#  'chiton': 117,
#  'chambered nautilus': 118,
#  'dungeness crab': 119,
#  'goldfinch': 12,
#  'rock crab': 120,
#  'fiddler crab': 121,
#  'king crab': 122,
#  'american lobster': 123,
#  'spiny lobster': 124,
#  'crayfish': 125,
#  'hermit crab': 126,
#  'isopod': 127,
#  'white stork': 128,
#  'black stork': 129,
#  'house finch': 13,
#  'spoonbill': 130,
#  'flamingo': 131,
#  'little blue heron': 132,
#  'american egret': 133,
#  'bittern': 134,
#  'crane': 135,
#  'limpkin': 136,
#  'european gallinule': 137,
#  'american coot': 138,
#  'bustard': 139,
#  'junco': 14,
# ...
